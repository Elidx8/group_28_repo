# %% [markdown]
# # [IAPR][iapr]: Lab 2 ‒  Object description
#
#
# **Group ID:** 28
#
# **Author 1 (sciper):** Elias Da Ros (315141)
#
# **Author 2 (sciper):** Luc Harrison (315788)
#
# **Author 3 (sciper):** Rim El Qabli (340997)
#
# **Release date:** 26.03.2025
# **Due date:** 09.04.2025 (11:59 pm)
#
#
# ## Key Submission Guidelines:
#
# - **Before submitting your notebook, <span style="color:red;">rerun</span> it from scratch!** Go to: `Kernel` > `Restart & Run All`
# - **Only groups of three will be accepted**, except in exceptional circumstances.
# - **You are not allowed to use any libraries** other than those provided in this notebook.
# - **TAs must be able to run your code from start to finish without any issues.**
# - **Failure to follow these guidelines may result in point deductions** during grading.
#
#
# [iapr]: https://github.com/LTS5/iapr2025

# %%
######################################################
############ Check it is python 3.9 ##################
## DO NOT COMMENT, WE WILL TEST YOUR CODE WITH 3.9 ###
######################################################

import sys 
assert (sys.version_info.major == 3) and (sys.version_info.minor == 9)

# %%
# # Install required packages
# %pip install wget -q
# %pip install numpy -q
# %pip install matplotlib -q
# %pip install scikit-image -q
# %pip install scikit-learn -q
# %pip install python-mnist -q
# %pip install opencv-python -q

# %%
# Import main packages
from utils.lab_02_utils import *
from skimage.morphology import remove_small_objects, remove_small_holes, closing, disk, opening
from skimage.transform import rotate, resize
from sklearn.metrics.pairwise import euclidean_distances
from skimage.measure import regionprops, find_contours

import cv2
import numpy as np

# %% [markdown]
# ---
# # Introduction
#
# In this lab, we will work with the famous MNIST dataset. It is composed of thousands of images (size 28x28) that depict handwritten digits from 0 to 9. The code below will automatically download the data from the online repo. This lab aims to create discriminant features from handwritten digits using various approaches.
#
#
# Take a look at the data to get a better idea of what you will be working within this lab.

# %%
images, labels = load_lab02_data()
# Out:
# Data downloaded under folder: ../data/data_lab_02
# 60000 Images and 60000 labels loaded

# %% [markdown]
# ---
# # Part 1 - Preprocessing [2 pts]
#
#
# In this lab, we will create different feautre descriptors from digits. However, we will not use all images in the dataset. We will focus on the digits "0" and "4".
#
# ## 1.1 Selection (1 pt)
#
# **Q1 (1 pt)** Your first task is to complete the function `extract_label` such that it selects from the input data only the images that are labeled as a given `target_label`. This function will be used to extract 0s and 4s from the data cohort. When running the code, the plots should only show you samples that are 0s (first plot) and 4s (second plot)

# %%
def extract_label(images: np.ndarray, labels: np.ndarray, target_label: int):
    """
    The function returns only the images that have target_label as labels.
    
    Args
    ----
    images: np.ndarray (N, 28, 28)
        Source images - handwritten digits 
    labels: np.ndarray (N)
        List of labels associated with the input image
    target_label: int
        Selected target label

    Return
    ------
    img_extract: np.ndarray (M, 28, 28)
        Extracted images that have target_label as label (M should be lower than N).
    """

    n, d, _ = np.shape(images) 
    img_extract = np.zeros((30, d, d))

    good_labels = (labels == target_label)
    img_extract = images[good_labels]
    
    return img_extract

# %%
################################################################
############################ TEST ##############################
################################################################

images_a, images_b = test_1_1(extract_label, images, labels)

# %% [markdown]
# ## 1.2 Preprocessing (1 pt)
#
# Before computing the Fourier descriptors we need to preprocess the images.
#
# * **Q1 (1 pt)**: Complete the function `preprocess` such that it cleans the input images. Take a look at the example images above and try to think what could be improved to allow better uniformity of the data. Take advantage of what you have learned in the previous lab.

# %%
def preprocess(images: np.ndarray):
    """
    Apply the processing step to images to achieve better data uniformity.
    
    Args
    ----
    images: np.ndarray (N, 28, 28)
        Source images

    Return
    ------
    img_process: np.ndarray (N, 28, 28)
        Processed images.
    """

    # Get the shape of input data and set dummy values
    n, d, _ = np.shape(images) 
    img_process = np.zeros_like(images)
    
    # Define a threshold to create a binary image
    threshold = 100
    img_process = np.where(images > threshold, 1, 0)
    
    # Apply opening => enhance object boundaries
    # Apply closing => fill small holes and smooth object shapes
    # remove_small_holes => to tranform 0 to disks

    # for i in range(n):
    #     img_process[i] = opening(binary_images[i], disk(1))
    #     img_process[i] = closing(binary_images[i], disk(2))
    #     img_process[i] = remove_small_holes(img_process[i],350)

        
    return img_process

# %%
################################################################
############################ TEST ##############################
################################################################

images_p_a, images_p_b = test_1_2(preprocess, images_a, images_b)

# %% [markdown]
# ---
# # Part 2 - Fourier Descriptors [17 pts]
#
#
# ## 2.1. Get contour and descriptors (9 pts)
#
# In this section, we will create Fourier descriptors from digits. The next step in our pipeline will be to detect the contours. To do so you can use existing algorithm available online such as `find_contours`([doc](https://scikit-image.org/docs/stable/api/skimage.measure.html#skimage.measure.find_contours)) from skcit-image or `findContours` ([doc](https://docs.opencv.org/4.x/d3/dc0/group__imgproc__shape.html#gadf1ad6a0b82947fa1fe3c3d497f260e0)) from opencv. Pay attention to the coordinate system when using the contour detection function (is the first component x or y coordinate?).
#
# * **Q1 (2 pts)**: Complete the function `find_contour` below such that it returns the contour estimations of the given images. The provided `display_samples` function will display the returned contours for a subset of images.

# %%
def find_contour(images: np.ndarray):
    """
    Find the contours for the set of images
    
    Args
    ----
    images: np.ndarray (N, 28, 28)
        Source images to process

    Return
    ------
    contours: list of np.ndarray
        List of N arrays containing the coordinates of the contour. Each element of the 
        list is an array of 2d coordinates (K, 2) where K depends on the number of elements 
        that form the contour. 
    """

    # Get number of images to process
    N, _, _ = np.shape(images)
    # Fill in dummy values (fake points)
    contours = [np.array([[0, 0], [1, 1]]) for i in range(N)]

    # ------------------
    # Your code here ... 
    for i in range(N):
        contours[i] = find_contours(images[i])[0]
        contours[i] = np.flip(contours[i], axis = 1)
        
    # ------------------
    
    return contours

# %%
################################################################
############################ TEST ##############################
################################################################

cnt_p_a, cnt_p_b = test_2_1(find_contour, images_p_a, images_p_b)
# Out:
# 1000

# %% [markdown]
# Now that we are able to properly detect shape contours, we can finally compute Fourier descriptors. However, we still face a small issue. The allow a fair comparison between the Fourier descriptors we need to ensure that all descriptors have the same length.
#
# * **Q2 (2 pts)**: Implement the function `compute_descriptor_padding` that takes as input the computed contours from before and returns the Fourier descriptors for each contour. Use `fft` ([doc](https://numpy.org/doc/stable/reference/generated/numpy.fft.fft.html#numpy.fft.fft)) from Numpy to compute the transformation. Use the `n_sample` argument to set the number of points to consider per contour. If the contour is longer than `n_sample` discard the extra points. If the contour is shorter than `n_sample`, use 0 paddings. Make sure that the first element of the descriptor represent the continuous component in the frequency domain.

# %%
def compute_descriptor_padding(contours: np.ndarray, n_samples: int = 11):
    """
    Compute Fourier descriptors of input images
    
    Args
    ----
    contours: list of np.ndarray
        List of N arrays containing the coordinates of the contour. Each element of the 
        list is an array of 2d coordinates (K, 2) where K depends on the number of elements 
        that form the contour. 
    n_samples: int
        Number of samples to consider. If the contour length is higher, discard the remaining part. If it is shorter, add padding.
        Make sure that the first element of the descriptor represents the continuous component.

    Return
    ------
    descriptors: np.ndarray complex (N, n_samples)
        Computed complex Fourier descriptors for the given input images
    """

    N = len(contours)
    # Look for the number of contours
    descriptors = np.zeros((N, n_samples), dtype=np.complex128)

    # ------------------
    # Your code here ... 
    for i, contour in enumerate(contours):
        if n_samples > len(contour):
            # Pad the contour with zeros if it is shorter than n_samples
            padding = np.zeros((n_samples - len(contour), 2))
            contour = np.vstack((contour, padding))
        elif n_samples < len(contour):
            # Truncate the contour if it is longer than n_samples
            contour = contour[:n_samples]
        descriptors[i] = np.fft.fft(contour[:, 0] + 1j * contour[:, 1]) # Define the contour points as complex numbers (for 1D DFT)

    # ------------------

    return descriptors

# %% [markdown]
# The code below uses the `plot_features` function to display the computed Fourier descriptors. We display the real, imaginary, and absolute components, respectively. Each color depicts a different digit. We use 2D plots to highlight the clustering capability of the components.
# * **Q3 (1 pt)**: Comment on the quality of the Fourier descriptors. Do you think they are good feature descriptors? (justify)
#     * **Answer**: When distinguisihing betweeen 0s and 4s, we could achieve good results when inspecting either the real or imaginary parts seperately, however using the abolute value would not enable us to correctly seperate both numbers.
# * **Q4 (1 pt)**: Knowing that we used `n_samples=11` to compute the Fourier transform, what do the components 0, 1, 5, and 10 represent as frequencies? (high, medium, constant, etc.)
#     * **Answer**: 0 represents the constant component, 1 the low frequencies, 5 the medium frequencies, and 10 the high frequencies.

# %%
################################################################
############################ TEST ##############################
################################################################

test_2_1_2(compute_descriptor_padding, cnt_p_a, cnt_p_b)

# %% [markdown]
# As you might have realized before, the computed Fourier descriptors do not help us to find an optimal separation between the digits. This mainly comes from the fact that using 0 padding is a cheap and inefficient way to ensure homogeneity in length for descriptors. A better solution would be to ensure that we have the same number of points along the contour for each digit. To do so, we need to implement a new function that will resample the contour such that we always have the same number of points no matter the shape.
#
# * **Q5 (2 pts)**: Implement the function `linear_interpolation` that takes as input the contours with various lengths and the wanted number of samples per contour for resampling. For each contour, resample the points such that each contour has the same length `n_samples`. We want the points to be uniformly distributed (same distance between points) along the contour. You can use for example the function `interp` ([doc](https://numpy.org/doc/stable/reference/generated/numpy.interp.html)) from Numpy to perform the interpolation. The function `display_samples` will display the contour for different lengths.
#
# **Hint**: Think about the contour as two distinct signals x(t) and y(t) that are evaluated at different time steps $t$. Here the time steps can be seen as the Euclidean distance between consecutive samples $t_i$ = $ \sum_{j=1}^{j \leq i} \sqrt{(x_{j} - x_{j-1})^2 + (y_{j} - y_{j-1})^2}$, and $t_0 = 0$. The aim here is to resample the function at new time steps $t_i' = i * \frac{t_{N-1}}{n_{samples} + 1}$ where $n_{samples}$ is the new number of points.

# %%
def linear_interpolation(contours: np.ndarray, n_samples: int = 11):
    """
    Perform interpolation/resampling of the contour across n_samples.
    
    Args
    ----
    contours: list of np.ndarray
        List of N arrays containing the coordinates of the contour. Each element of the 
        list is an array of 2d coordinates (K, 2) where K depends on the number of elements 
        that form the contour. 
    n_samples: int
        Number of samples to consider along the contour.

    Return
    ------
    contours_inter: np.ndarray (N, n_samples, 2)
        Interpolated contour with n_samples
    """

    N = len(contours)
    contours_inter = np.zeros((N, n_samples, 2))
    
    # ------------------
    # Your code here ... 
    for i, contour in enumerate(contours):
        # print(contour.shape)
        diff = np.sum(np.diff(contour, axis = 0)**2, axis = 1)
        cumsum = np.cumsum(diff, axis = 0)
        # Add (0, 0) to the beginning of the cumsum array
        t = np.insert(cumsum, 0, 0) # t0 = 0
        # print(t)
        t_interpolate = [i * (t[-1]) / (n_samples + 1) for i in range(n_samples)]
        
        x_new = np.interp(t_interpolate, t, contour[:, 0])
        y_new = np.interp(t_interpolate, t, contour[:, 1])
        
        contours_inter[i] = np.array([x_new, y_new]).T
        
        
    
    # ------------------
        
    return contours_inter

# %%
################################################################
############################ TEST ##############################
################################################################

test_2_1_5(linear_interpolation, cnt_p_a, images_p_a)

# %% [markdown]
# Now that we have implemented our resampling approach we can revisualize the clustering efficiency of our descriptors.
#
# * **Q6 (1 pt)**: Comment on the quality of the descriptors. Is it better than before? is there a frequency/component that appears to work better? Does it make sense?
#     * **Answer**: The descriptors are better after resampling, with low frequency components being more clustered, this makes sense since these components capture the overall shape of the contour which is more consistent and less noise, meaning that we can now use these low frequency descriptors to distinguish between both numbers

# %%
################################################################
############################ TEST ##############################
################################################################

feat_a, feat_b = test_2_1_6(compute_descriptor_padding, linear_interpolation, cnt_p_a, cnt_p_b, n_samples=11)

# %% [markdown]
# ## 2.2. Reconstruction (2 pts)
#
# For this part, we will now try to go the other way. Given a Fourier descriptor we will try to retrieve the original shape.
# * **Q1 (1 pt)** Implement the function `compute_reverse_descriptor` that takes as input a single descriptor and reverses it to x and y coordinates given a number of samples `n_samples`. Use the function `ifft` ([doc](https://numpy.org/doc/stable/reference/generated/numpy.fft.ifft.html)) from Numpy.

# %%
def compute_reverse_descriptor(descriptor: np.ndarray, n_samples: int = 11):
    """
    Reverse a Fourier descriptor to xy coordinates given a number of samples.
    
    Args
    ----
    descriptor: np.ndarray (D,)
        Complex descriptor of length D.
    n_samples: int
        Number of samples to consider to reverse transformation.

    Return
    ------
    x: np.ndarray complex (n_samples,)
        x coordinates of the contour
    y: np.ndarray complex (n_samples,)
        y coordinates of the contour
    """

    x = np.zeros(n_samples)
    y = np.zeros(n_samples)
    
    # ------------------
    # Your code here ... 
    ifft = np.fft.ifft(descriptor)
    x = ifft.real
    y = ifft.imag
    # ------------------

    return x, y

# %% [markdown]
# With the function `plot_reconstruction` we plot an example of the reconstruction of the digits. We display the result as we progressively add more frequencies. We start with the first component (component 0) and then add frequency pairs from low to high frequencies.
#
# * **Q2 (1 pt)**: Based on your observation, do you think 11 samples are enough to properly describe the digits below? (justify)
#     * **Answer**: With only 11 samples, we can properly describe a 0, however it is not enough to describe a 4, this is because the number 4 has more high frequency components, so we need more descriptors to describe it well.

# %%
################################################################
############################ TEST ##############################
################################################################

test_2_2(images_p_a , images_p_b, feat_a, feat_b, compute_reverse_descriptor)

# %% [markdown]
# ## 2.3. Invariance (6 pts)
#
# For the last part with Fourier descriptors, we will check for descriptors invariance. As seen in class, if handled properly Fourier descriptors can be invariant to translation, rotation, and scaling.
#
# * **Q1 (3 pts)**: Implement the functions `apply_rotation`, `apply_scaling`, and `apply_translate` to apply random rotation, scaling, and translation to input images. For scaling and translation, we recommend avoiding large values where the digits are cropped (out of frame). You can use the `random` package ([doc](https://numpy.org/doc/1.16/reference/routines.random.html)) from Numpy to generate random values.

# %%
def apply_rotation(img: np.ndarray):
    """
    Apply random rotation to input the image
    
    Args
    ----
    image: np.ndarray (28, 28)
        Source images
        
    Return
    ------
    rotated: np.ndarray (28, 28)
        Rotated source images
    """

    rotated = np.zeros_like(img)
    
    # ------------------
    # Your code here ... 
    random_angle = np.random.randint(0, 360)
        
    # Rotate the image
    rotated = rotate(img, random_angle, resize=False)
    # ------------------
    
    return rotated


def apply_scaling(img: np.ndarray):
    """
    Apply random scaling to input image
    
    Args
    ----
    image: np.ndarray (28, 28)
        Source images
        
    Return
    ------
    scaled: np.ndarray (28, 28)
        Scaled source images
    """
    
    scaled = np.zeros_like(img)
    
    # ------------------
    # Your code here ... 
    random_resize = np.random.uniform(0.7,1)
    scaled = resize(img, (int(28*random_resize), int(28*random_resize)))
    # ------------------
    
    return scaled

def apply_translate(img: np.ndarray):
    """
    Apply random x and y translation to input image
    
    Args
    ----
    image: np.ndarray (28, 28)
        Source images
        
    Return
    ------
    translated: np.ndarray (28, 28)
        Translated source images
    """
    
    translated = np.zeros_like(img)
    
    # ------------------
    # Your code here ... 
    # Generate random translations for x and y between -5 and 5 pixels
    x_offset = int(np.random.uniform(-5, 5))
    y_offset = int(np.random.uniform(-5, 5))
    
    # Compute the ranges for the original and translated images
    x_start_src = max(0, -x_offset)
    x_end_src = min(28, 28 - x_offset)
    y_start_src = max(0, -y_offset)
    y_end_src = min(28, 28 - y_offset)
    
    x_start_dst = max(0, x_offset)
    x_end_dst = min(28, 28 + x_offset)
    y_start_dst = max(0, y_offset)
    y_end_dst = min(28, 28 + y_offset)
    
    # Copy the pixels from the source to the translated image
    translated[x_start_dst:x_end_dst, y_start_dst:y_end_dst] = img[x_start_src:x_end_src, y_start_src:y_end_src]
    
    # ------------------
    
    return translated

# %%
################################################################
############################ TEST ##############################
################################################################

test_2_3(apply_rotation, apply_scaling, apply_translate, images_p_a[0])

# %% [markdown]
# Now that we implemented our transformation, we can test for feature invariance. To assess the robustness of the Fourier descriptors to image transformations, we compute the error between the original descriptors (before transformation) to the one after transformation.
#
# * **Q2 (1 pt)**: Complet the function `translation_invariant` to make the Fourier deciptor invariant to translation. Does the error decrease after treatment for translation invariance? Is it null, if not why?
#     * **Answer**: After making the image translation invariant, the error is 0, this occurs because, to make it translation invariant, we remove the offset component, the only one that a translation would affect.

# %%
def translation_invariant(features):
    """
    Make input Fourier descriptors invariant to translation.

    Args
    ----
    features: np.ndarray (N, D)
        The Fourier descriptors of N images over D features.

    Return
    ------
    features_inv: np.ndarray (N, K)
        The Fourier descriptors invariant to translation of N images 
        over K (K <= N) features.
    """

    # Set default values
    features_inv = np.zeros_like(features)
    
    # ------------------
    # Your code here ...
    features_inv[:, 0] = 0 # Set the offset to zero
    # ------------------
    
    return features_inv

# %%
################################################################
############################ TEST ##############################
################################################################

feat_t_a = test_2_3_2(translation_invariant, find_contour, apply_translate, compute_descriptor_padding, linear_interpolation,images_p_a, feat_a)
# Out:
# Translation error: 6.36
# Corrected translation error: 0.00

# %% [markdown]
# * **Q3 (1 pt)**: Complet the function `rotation_invariant` to make the Fourier deciptor invariant to rotation. Does the error decrease after treatment for rotation invariance? Do you think that selecting specific rotation angles might help the error to decrease even lower?
#     * **Answer**: ...

# %%
def rotation_invariant(features):
    """
    Make input Fourier descriptors invariant to rotation.

    Args
    ----
    features: np.ndarray (N, D)
        The Fourier descriptors of N images over D features.

    Return
    ------
    features_inv: np.ndarray (N, K)
        The Fourier descriptors invariant to rotation of N images 
        over K (K <= N) features.
    """

    # Set default values
    features_inv = np.zeros_like(features)
    
    # ------------------
    # Your code here ... 
    features_inv = np.abs(features)
    # ------------------

    return features_inv

# %%
################################################################
############################ TEST ##############################
################################################################

test_2_3_3(rotation_invariant, find_contour, apply_rotation, compute_descriptor_padding, linear_interpolation,images_p_a, feat_a)
# Out:
# Warning: No contours found for image 0.
# Warning: No contours found for image 1.
# Warning: No contours found for image 2.
# Warning: No contours found for image 3.
# Warning: No contours found for image 4.
# Warning: No contours found for image 5.
# Warning: No contours found for image 6.
# Warning: No contours found for image 7.
# Warning: No contours found for image 8.
# Warning: No contours found for image 9.
# Warning: No contours found for image 10.
# Warning: No contours found for image 11.
# Warning: No contours found for image 12.
# Warning: No contours found for image 13.
# Warning: No contours found for image 14.
# Warning: No contours found for image 15.
# Warning: No contours found for image 16.
# Warning: No contours found for image 17.
# Warning: No contours found for image 18.
# Warning: No contours found for image 19.
# Warning: No contours found for image 20.
# Warning: No contours found for image 21.
# Warning: No contours found for image 22.
# Warning: No contours found for image 23.
# Warning: No contours found for image 24.
# Warning: No contours found for image 25.
# Warning: No contours found for image 26.
# Warning: No contours found for image 27.
# Warning: No contours found for image 28.
# Warning: No contours found for image 29.
# Warning: No contours found for image 30.
# Warning: No contours found for image 31.
# Warning: No contours found for image 32.
# Warning: No contours found for image 33.
# Warning: No contours found for image 34.
# Warning: No contours found for image 35.
# Warning: No contours found for image 36.
# Warning: No contours found for image 37.
# Warning: No contours found for image 38.
# Warning: No contours found for image 39.
# Warning: No contours found for image 40.
# Warning: No contours found for image 41.
# Warning: No contours found for image 42.
# Warning: No contours found for image 43.
# Warning: No contours found for image 44.
# Warning: No contours found for image 45.
# Warning: No contours found for image 46.
# Warning: No contours found for image 47.
# Warning: No contours found for image 48.
# Warning: No contours found for image 49.
# Warning: No contours found for image 50.
# Warning: No contours found for image 51.
# Warning: No contours found for image 52.
# Warning: No contours found for image 53.
# Warning: No contours found for image 54.
# Warning: No contours found for image 55.
# Warning: No contours found for image 56.
# Warning: No contours found for image 57.
# Warning: No contours found for image 58.
# Warning: No contours found for image 59.
# Warning: No contours found for image 60.
# Warning: No contours found for image 61.
# Warning: No contours found for image 62.
# Warning: No contours found for image 63.
# Warning: No contours found for image 64.
# Warning: No contours found for image 65.
# Warning: No contours found for image 66.
# Warning: No contours found for image 67.
# Warning: No contours found for image 68.
# Warning: No contours found for image 69.
# Warning: No contours found for image 70.
# Warning: No contours found for image 71.
# Warning: No contours found for image 72.
# Warning: No contours found for image 73.
# Warning: No contours found for image 74.
# Warning: No contours found for image 75.
# Warning: No contours found for image 76.
# Warning: No contours found for image 77.
# Warning: No contours found for image 78.
# Warning: No contours found for image 79.
# Warning: No contours found for image 80.
# Warning: No contours found for image 81.
# Warning: No contours found for image 82.
# Warning: No contours found for image 83.
# Warning: No contours found for image 84.
# Warning: No contours found for image 85.
# Warning: No contours found for image 86.
# Warning: No contours found for image 87.
# Warning: No contours found for image 88.
# Warning: No contours found for image 89.
# Warning: No contours found for image 90.
# Warning: No contours found for image 91.
# Warning: No contours found for image 92.
# Warning: No contours found for image 93.
# Warning: No contours found for image 94.
# Warning: No contours found for image 95.
# Warning: No contours found for image 96.
# Warning: No contours found for image 97.
# Warning: No contours found for image 98.
# Warning: No contours found for image 99.
# Warning: No contours found for image 100.
# Warning: No contours found for image 101.
# Warning: No contours found for image 102.
# Warning: No contours found for image 103.
# Warning: No contours found for image 104.
# Warning: No contours found for image 105.
# Warning: No contours found for image 106.
# Warning: No contours found for image 107.
# Warning: No contours found for image 108.
# Warning: No contours found for image 109.
# Warning: No contours found for image 110.
# Warning: No contours found for image 111.
# Warning: No contours found for image 112.
# Warning: No contours found for image 113.
# Warning: No contours found for image 114.
# Warning: No contours found for image 115.
# Warning: No contours found for image 116.
# Warning: No contours found for image 117.
# Warning: No contours found for image 118.
# Warning: No contours found for image 119.
# Warning: No contours found for image 120.
# Warning: No contours found for image 121.
# Warning: No contours found for image 122.
# Warning: No contours found for image 123.
# Warning: No contours found for image 124.
# Warning: No contours found for image 125.
# Warning: No contours found for image 126.
# Warning: No contours found for image 127.
# Warning: No contours found for image 128.
# Warning: No contours found for image 129.
# Warning: No contours found for image 130.
# Warning: No contours found for image 131.
# Warning: No contours found for image 132.
# Warning: No contours found for image 133.
# Warning: No contours found for image 134.
# Warning: No contours found for image 135.
# Warning: No contours found for image 136.
# Warning: No contours found for image 137.
# Warning: No contours found for image 138.
# Warning: No contours found for image 139.
# Warning: No contours found for image 140.
# Warning: No contours found for image 141.
# Warning: No contours found for image 142.
# Warning: No contours found for image 143.
# Warning: No contours found for image 144.
# Warning: No contours found for image 145.
# Warning: No contours found for image 146.
# Warning: No contours found for image 147.
# Warning: No contours found for image 148.
# Warning: No contours found for image 149.
# Warning: No contours found for image 150.
# Warning: No contours found for image 151.
# Warning: No contours found for image 152.
# Warning: No contours found for image 153.
# Warning: No contours found for image 154.
# Warning: No contours found for image 155.
# Warning: No contours found for image 156.
# Warning: No contours found for image 157.
# Warning: No contours found for image 158.
# Warning: No contours found for image 159.
# Warning: No contours found for image 160.
# Warning: No contours found for image 161.
# Warning: No contours found for image 162.
# Warning: No contours found for image 163.
# Warning: No contours found for image 164.
# Warning: No contours found for image 165.
# Warning: No contours found for image 166.
# Warning: No contours found for image 167.
# Warning: No contours found for image 168.
# Warning: No contours found for image 169.
# Warning: No contours found for image 170.
# Warning: No contours found for image 171.
# Warning: No contours found for image 172.
# Warning: No contours found for image 173.
# Warning: No contours found for image 174.
# Warning: No contours found for image 175.
# Warning: No contours found for image 176.
# Warning: No contours found for image 177.
# Warning: No contours found for image 178.
# Warning: No contours found for image 179.
# Warning: No contours found for image 180.
# Warning: No contours found for image 181.
# Warning: No contours found for image 182.
# Warning: No contours found for image 183.
# Warning: No contours found for image 184.
# Warning: No contours found for image 185.
# Warning: No contours found for image 186.
# Warning: No contours found for image 187.
# Warning: No contours found for image 188.
# Warning: No contours found for image 189.
# Warning: No contours found for image 190.
# Warning: No contours found for image 191.
# Warning: No contours found for image 192.
# Warning: No contours found for image 193.
# Warning: No contours found for image 194.
# Warning: No contours found for image 195.
# Warning: No contours found for image 196.
# Warning: No contours found for image 197.
# Warning: No contours found for image 198.
# Warning: No contours found for image 199.
# Warning: No contours found for image 200.
# Warning: No contours found for image 201.
# Warning: No contours found for image 202.
# Warning: No contours found for image 203.
# Warning: No contours found for image 204.
# Warning: No contours found for image 205.
# Warning: No contours found for image 206.
# Warning: No contours found for image 207.
# Warning: No contours found for image 208.
# Warning: No contours found for image 209.
# Warning: No contours found for image 210.
# Warning: No contours found for image 211.
# Warning: No contours found for image 212.
# Warning: No contours found for image 213.
# Warning: No contours found for image 214.
# Warning: No contours found for image 215.
# Warning: No contours found for image 216.
# Warning: No contours found for image 217.
# Warning: No contours found for image 218.
# Warning: No contours found for image 219.
# Warning: No contours found for image 220.
# Warning: No contours found for image 221.
# Warning: No contours found for image 222.
# Warning: No contours found for image 223.
# Warning: No contours found for image 224.
# Warning: No contours found for image 225.
# Warning: No contours found for image 226.
# Warning: No contours found for image 227.
# Warning: No contours found for image 228.
# Warning: No contours found for image 229.
# Warning: No contours found for image 230.
# Warning: No contours found for image 231.
# Warning: No contours found for image 232.
# Warning: No contours found for image 233.
# Warning: No contours found for image 234.
# Warning: No contours found for image 235.
# Warning: No contours found for image 236.
# Warning: No contours found for image 237.
# Warning: No contours found for image 238.
# Warning: No contours found for image 239.
# Warning: No contours found for image 240.
# Warning: No contours found for image 241.
# Warning: No contours found for image 242.
# Warning: No contours found for image 243.
# Warning: No contours found for image 244.
# Warning: No contours found for image 245.
# Warning: No contours found for image 246.
# Warning: No contours found for image 247.
# Warning: No contours found for image 248.
# Warning: No contours found for image 249.
# Warning: No contours found for image 250.
# Warning: No contours found for image 251.
# Warning: No contours found for image 252.
# Warning: No contours found for image 253.
# Warning: No contours found for image 254.
# Warning: No contours found for image 255.
# Warning: No contours found for image 256.
# Warning: No contours found for image 257.
# Warning: No contours found for image 258.
# Warning: No contours found for image 259.
# Warning: No contours found for image 260.
# Warning: No contours found for image 261.
# Warning: No contours found for image 262.
# Warning: No contours found for image 263.
# Warning: No contours found for image 264.
# Warning: No contours found for image 265.
# Warning: No contours found for image 266.
# Warning: No contours found for image 267.
# Warning: No contours found for image 268.
# Warning: No contours found for image 269.
# Warning: No contours found for image 270.
# Warning: No contours found for image 271.
# Warning: No contours found for image 272.
# Warning: No contours found for image 273.
# Warning: No contours found for image 274.
# Warning: No contours found for image 275.
# Warning: No contours found for image 276.
# Warning: No contours found for image 277.
# Warning: No contours found for image 278.
# Warning: No contours found for image 279.
# Warning: No contours found for image 280.
# Warning: No contours found for image 281.
# Warning: No contours found for image 282.
# Warning: No contours found for image 283.
# Warning: No contours found for image 284.
# Warning: No contours found for image 285.
# Warning: No contours found for image 286.
# Warning: No contours found for image 287.
# Warning: No contours found for image 288.
# Warning: No contours found for image 289.
# Warning: No contours found for image 290.
# Warning: No contours found for image 291.
# Warning: No contours found for image 292.
# Warning: No contours found for image 293.
# Warning: No contours found for image 294.
# Warning: No contours found for image 295.
# Warning: No contours found for image 296.
# Warning: No contours found for image 297.
# Warning: No contours found for image 298.
# Warning: No contours found for image 299.
# Warning: No contours found for image 300.
# Warning: No contours found for image 301.
# Warning: No contours found for image 302.
# Warning: No contours found for image 303.
# Warning: No contours found for image 304.
# Warning: No contours found for image 305.
# Warning: No contours found for image 306.
# Warning: No contours found for image 307.
# Warning: No contours found for image 308.
# Warning: No contours found for image 309.
# Warning: No contours found for image 310.
# Warning: No contours found for image 311.
# Warning: No contours found for image 312.
# Warning: No contours found for image 313.
# Warning: No contours found for image 314.
# Warning: No contours found for image 315.
# Warning: No contours found for image 316.
# Warning: No contours found for image 317.
# Warning: No contours found for image 318.
# Warning: No contours found for image 319.
# Warning: No contours found for image 320.
# Warning: No contours found for image 321.
# Warning: No contours found for image 322.
# Warning: No contours found for image 323.
# Warning: No contours found for image 324.
# Warning: No contours found for image 325.
# Warning: No contours found for image 326.
# Warning: No contours found for image 327.
# Warning: No contours found for image 328.
# Warning: No contours found for image 329.
# Warning: No contours found for image 330.
# Warning: No contours found for image 331.
# Warning: No contours found for image 332.
# Warning: No contours found for image 333.
# Warning: No contours found for image 334.
# Warning: No contours found for image 335.
# Warning: No contours found for image 336.
# Warning: No contours found for image 337.
# Warning: No contours found for image 338.
# Warning: No contours found for image 339.
# Warning: No contours found for image 340.
# Warning: No contours found for image 341.
# Warning: No contours found for image 342.
# Warning: No contours found for image 343.
# Warning: No contours found for image 344.
# Warning: No contours found for image 345.
# Warning: No contours found for image 346.
# Warning: No contours found for image 347.
# Warning: No contours found for image 348.
# Warning: No contours found for image 349.
# Warning: No contours found for image 350.
# Warning: No contours found for image 351.
# Warning: No contours found for image 352.
# Warning: No contours found for image 353.
# Warning: No contours found for image 354.
# Warning: No contours found for image 355.
# Warning: No contours found for image 356.
# Warning: No contours found for image 357.
# Warning: No contours found for image 358.
# Warning: No contours found for image 359.
# Warning: No contours found for image 360.
# Warning: No contours found for image 361.
# Warning: No contours found for image 362.
# Warning: No contours found for image 363.
# Warning: No contours found for image 364.
# Warning: No contours found for image 365.
# Warning: No contours found for image 366.
# Warning: No contours found for image 367.
# Warning: No contours found for image 368.
# Warning: No contours found for image 369.
# Warning: No contours found for image 370.
# Warning: No contours found for image 371.
# Warning: No contours found for image 372.
# Warning: No contours found for image 373.
# Warning: No contours found for image 374.
# Warning: No contours found for image 375.
# Warning: No contours found for image 376.
# Warning: No contours found for image 377.
# Warning: No contours found for image 378.
# Warning: No contours found for image 379.
# Warning: No contours found for image 380.
# Warning: No contours found for image 381.
# Warning: No contours found for image 382.
# Warning: No contours found for image 383.
# Warning: No contours found for image 384.
# Warning: No contours found for image 385.
# Warning: No contours found for image 386.
# Warning: No contours found for image 387.
# Warning: No contours found for image 388.
# Warning: No contours found for image 389.
# Warning: No contours found for image 390.
# Warning: No contours found for image 391.
# Warning: No contours found for image 392.
# Warning: No contours found for image 393.
# Warning: No contours found for image 394.
# Warning: No contours found for image 395.
# Warning: No contours found for image 396.
# Warning: No contours found for image 397.
# Warning: No contours found for image 398.
# Warning: No contours found for image 399.
# Warning: No contours found for image 400.
# Warning: No contours found for image 401.
# Warning: No contours found for image 402.
# Warning: No contours found for image 403.
# Warning: No contours found for image 404.
# Warning: No contours found for image 405.
# Warning: No contours found for image 406.
# Warning: No contours found for image 407.
# Warning: No contours found for image 408.
# Warning: No contours found for image 409.
# Warning: No contours found for image 410.
# Warning: No contours found for image 411.
# Warning: No contours found for image 412.
# Warning: No contours found for image 413.
# Warning: No contours found for image 414.
# Warning: No contours found for image 415.
# Warning: No contours found for image 416.
# Warning: No contours found for image 417.
# Warning: No contours found for image 418.
# Warning: No contours found for image 419.
# Warning: No contours found for image 420.
# Warning: No contours found for image 421.
# Warning: No contours found for image 422.
# Warning: No contours found for image 423.
# Warning: No contours found for image 424.
# Warning: No contours found for image 425.
# Warning: No contours found for image 426.
# Warning: No contours found for image 427.
# Warning: No contours found for image 428.
# Warning: No contours found for image 429.
# Warning: No contours found for image 430.
# Warning: No contours found for image 431.
# Warning: No contours found for image 432.
# Warning: No contours found for image 433.
# Warning: No contours found for image 434.
# Warning: No contours found for image 435.
# Warning: No contours found for image 436.
# Warning: No contours found for image 437.
# Warning: No contours found for image 438.
# Warning: No contours found for image 439.
# Warning: No contours found for image 440.
# Warning: No contours found for image 441.
# Warning: No contours found for image 442.
# Warning: No contours found for image 443.
# Warning: No contours found for image 444.
# Warning: No contours found for image 445.
# Warning: No contours found for image 446.
# Warning: No contours found for image 447.
# Warning: No contours found for image 448.
# Warning: No contours found for image 449.
# Warning: No contours found for image 450.
# Warning: No contours found for image 451.
# Warning: No contours found for image 452.
# Warning: No contours found for image 453.
# Warning: No contours found for image 454.
# Warning: No contours found for image 455.
# Warning: No contours found for image 456.
# Warning: No contours found for image 457.
# Warning: No contours found for image 458.
# Warning: No contours found for image 459.
# Warning: No contours found for image 460.
# Warning: No contours found for image 461.
# Warning: No contours found for image 462.
# Warning: No contours found for image 463.
# Warning: No contours found for image 464.
# Warning: No contours found for image 465.
# Warning: No contours found for image 466.
# Warning: No contours found for image 467.
# Warning: No contours found for image 468.
# Warning: No contours found for image 469.
# Warning: No contours found for image 470.
# Warning: No contours found for image 471.
# Warning: No contours found for image 472.
# Warning: No contours found for image 473.
# Warning: No contours found for image 474.
# Warning: No contours found for image 475.
# Warning: No contours found for image 476.
# Warning: No contours found for image 477.
# Warning: No contours found for image 478.
# Warning: No contours found for image 479.
# Warning: No contours found for image 480.
# Warning: No contours found for image 481.
# Warning: No contours found for image 482.
# Warning: No contours found for image 483.
# Warning: No contours found for image 484.
# Warning: No contours found for image 485.
# Warning: No contours found for image 486.
# Warning: No contours found for image 487.
# Warning: No contours found for image 488.
# Warning: No contours found for image 489.
# Warning: No contours found for image 490.
# Warning: No contours found for image 491.
# Warning: No contours found for image 492.
# Warning: No contours found for image 493.
# Warning: No contours found for image 494.
# Warning: No contours found for image 495.
# Warning: No contours found for image 496.
# Warning: No contours found for image 497.
# Warning: No contours found for image 498.
# Warning: No contours found for image 499.
# Warning: No contours found for image 500.
# Warning: No contours found for image 501.
# Warning: No contours found for image 502.
# Warning: No contours found for image 503.
# Warning: No contours found for image 504.
# Warning: No contours found for image 505.
# Warning: No contours found for image 506.
# Warning: No contours found for image 507.
# Warning: No contours found for image 508.
# Warning: No contours found for image 509.
# Warning: No contours found for image 510.
# Warning: No contours found for image 511.
# Warning: No contours found for image 512.
# Warning: No contours found for image 513.
# Warning: No contours found for image 514.
# Warning: No contours found for image 515.
# Warning: No contours found for image 516.
# Warning: No contours found for image 517.
# Warning: No contours found for image 518.
# Warning: No contours found for image 519.
# Warning: No contours found for image 520.
# Warning: No contours found for image 521.
# Warning: No contours found for image 522.
# Warning: No contours found for image 523.
# Warning: No contours found for image 524.
# Warning: No contours found for image 525.
# Warning: No contours found for image 526.
# Warning: No contours found for image 527.
# Warning: No contours found for image 528.
# Warning: No contours found for image 529.
# Warning: No contours found for image 530.
# Warning: No contours found for image 531.
# Warning: No contours found for image 532.
# Warning: No contours found for image 533.
# Warning: No contours found for image 534.
# Warning: No contours found for image 535.
# Warning: No contours found for image 536.
# Warning: No contours found for image 537.
# Warning: No contours found for image 538.
# Warning: No contours found for image 539.
# Warning: No contours found for image 540.
# Warning: No contours found for image 541.
# Warning: No contours found for image 542.
# Warning: No contours found for image 543.
# Warning: No contours found for image 544.
# Warning: No contours found for image 545.
# Warning: No contours found for image 546.
# Warning: No contours found for image 547.
# Warning: No contours found for image 548.
# Warning: No contours found for image 549.
# Warning: No contours found for image 550.
# Warning: No contours found for image 551.
# Warning: No contours found for image 552.
# Warning: No contours found for image 553.
# Warning: No contours found for image 554.
# Warning: No contours found for image 555.
# Warning: No contours found for image 556.
# Warning: No contours found for image 557.
# Warning: No contours found for image 558.
# Warning: No contours found for image 559.
# Warning: No contours found for image 560.
# Warning: No contours found for image 561.
# Warning: No contours found for image 562.
# Warning: No contours found for image 563.
# Warning: No contours found for image 564.
# Warning: No contours found for image 565.
# Warning: No contours found for image 566.
# Warning: No contours found for image 567.
# Warning: No contours found for image 568.
# Warning: No contours found for image 569.
# Warning: No contours found for image 570.
# Warning: No contours found for image 571.
# Warning: No contours found for image 572.
# Warning: No contours found for image 573.
# Warning: No contours found for image 574.
# Warning: No contours found for image 575.
# Warning: No contours found for image 576.
# Warning: No contours found for image 577.
# Warning: No contours found for image 578.
# Warning: No contours found for image 579.
# Warning: No contours found for image 580.
# Warning: No contours found for image 581.
# Warning: No contours found for image 582.
# Warning: No contours found for image 583.
# Warning: No contours found for image 584.
# Warning: No contours found for image 585.
# Warning: No contours found for image 586.
# Warning: No contours found for image 587.
# Warning: No contours found for image 588.
# Warning: No contours found for image 589.
# Warning: No contours found for image 590.
# Warning: No contours found for image 591.
# Warning: No contours found for image 592.
# Warning: No contours found for image 593.
# Warning: No contours found for image 594.
# Warning: No contours found for image 595.
# Warning: No contours found for image 596.
# Warning: No contours found for image 597.
# Warning: No contours found for image 598.
# Warning: No contours found for image 599.
# Warning: No contours found for image 600.
# Warning: No contours found for image 601.
# Warning: No contours found for image 602.
# Warning: No contours found for image 603.
# Warning: No contours found for image 604.
# Warning: No contours found for image 605.
# Warning: No contours found for image 606.
# Warning: No contours found for image 607.
# Warning: No contours found for image 608.
# Warning: No contours found for image 609.
# Warning: No contours found for image 610.
# Warning: No contours found for image 611.
# Warning: No contours found for image 612.
# Warning: No contours found for image 613.
# Warning: No contours found for image 614.
# Warning: No contours found for image 615.
# Warning: No contours found for image 616.
# Warning: No contours found for image 617.
# Warning: No contours found for image 618.
# Warning: No contours found for image 619.
# Warning: No contours found for image 620.
# Warning: No contours found for image 621.
# Warning: No contours found for image 622.
# Warning: No contours found for image 623.
# Warning: No contours found for image 624.
# Warning: No contours found for image 625.
# Warning: No contours found for image 626.
# Warning: No contours found for image 627.
# Warning: No contours found for image 628.
# Warning: No contours found for image 629.
# Warning: No contours found for image 630.
# Warning: No contours found for image 631.
# Warning: No contours found for image 632.
# Warning: No contours found for image 633.
# Warning: No contours found for image 634.
# Warning: No contours found for image 635.
# Warning: No contours found for image 636.
# Warning: No contours found for image 637.
# Warning: No contours found for image 638.
# Warning: No contours found for image 639.
# Warning: No contours found for image 640.
# Warning: No contours found for image 641.
# Warning: No contours found for image 642.
# Warning: No contours found for image 643.
# Warning: No contours found for image 644.
# Warning: No contours found for image 645.
# Warning: No contours found for image 646.
# Warning: No contours found for image 647.
# Warning: No contours found for image 648.
# Warning: No contours found for image 649.
# Warning: No contours found for image 650.
# Warning: No contours found for image 651.
# Warning: No contours found for image 652.
# Warning: No contours found for image 653.
# Warning: No contours found for image 654.
# Warning: No contours found for image 655.
# Warning: No contours found for image 656.
# Warning: No contours found for image 657.
# Warning: No contours found for image 658.
# Warning: No contours found for image 659.
# Warning: No contours found for image 660.
# Warning: No contours found for image 661.
# Warning: No contours found for image 662.
# Warning: No contours found for image 663.
# Warning: No contours found for image 664.
# Warning: No contours found for image 665.
# Warning: No contours found for image 666.
# Warning: No contours found for image 667.
# Warning: No contours found for image 668.
# Warning: No contours found for image 669.
# Warning: No contours found for image 670.
# Warning: No contours found for image 671.
# Warning: No contours found for image 672.
# Warning: No contours found for image 673.
# Warning: No contours found for image 674.
# Warning: No contours found for image 675.
# Warning: No contours found for image 676.
# Warning: No contours found for image 677.
# Warning: No contours found for image 678.
# Warning: No contours found for image 679.
# Warning: No contours found for image 680.
# Warning: No contours found for image 681.
# Warning: No contours found for image 682.
# Warning: No contours found for image 683.
# Warning: No contours found for image 684.
# Warning: No contours found for image 685.
# Warning: No contours found for image 686.
# Warning: No contours found for image 687.
# Warning: No contours found for image 688.
# Warning: No contours found for image 689.
# Warning: No contours found for image 690.
# Warning: No contours found for image 691.
# Warning: No contours found for image 692.
# Warning: No contours found for image 693.
# Warning: No contours found for image 694.
# Warning: No contours found for image 695.
# Warning: No contours found for image 696.
# Warning: No contours found for image 697.
# Warning: No contours found for image 698.
# Warning: No contours found for image 699.
# Warning: No contours found for image 700.
# Warning: No contours found for image 701.
# Warning: No contours found for image 702.
# Warning: No contours found for image 703.
# Warning: No contours found for image 704.
# Warning: No contours found for image 705.
# Warning: No contours found for image 706.
# Warning: No contours found for image 707.
# Warning: No contours found for image 708.
# Warning: No contours found for image 709.
# Warning: No contours found for image 710.
# Warning: No contours found for image 711.
# Warning: No contours found for image 712.
# Warning: No contours found for image 713.
# Warning: No contours found for image 714.
# Warning: No contours found for image 715.
# Warning: No contours found for image 716.
# Warning: No contours found for image 717.
# Warning: No contours found for image 718.
# Warning: No contours found for image 719.
# Warning: No contours found for image 720.
# Warning: No contours found for image 721.
# Warning: No contours found for image 722.
# Warning: No contours found for image 723.
# Warning: No contours found for image 724.
# Warning: No contours found for image 725.
# Warning: No contours found for image 726.
# Warning: No contours found for image 727.
# Warning: No contours found for image 728.
# Warning: No contours found for image 729.
# Warning: No contours found for image 730.
# Warning: No contours found for image 731.
# Warning: No contours found for image 732.
# Warning: No contours found for image 733.
# Warning: No contours found for image 734.
# Warning: No contours found for image 735.
# Warning: No contours found for image 736.
# Warning: No contours found for image 737.
# Warning: No contours found for image 738.
# Warning: No contours found for image 739.
# Warning: No contours found for image 740.
# Warning: No contours found for image 741.
# Warning: No contours found for image 742.
# Warning: No contours found for image 743.
# Warning: No contours found for image 744.
# Warning: No contours found for image 745.
# Warning: No contours found for image 746.
# Warning: No contours found for image 747.
# Warning: No contours found for image 748.
# Warning: No contours found for image 749.
# Warning: No contours found for image 750.
# Warning: No contours found for image 751.
# Warning: No contours found for image 752.
# Warning: No contours found for image 753.
# Warning: No contours found for image 754.
# Warning: No contours found for image 755.
# Warning: No contours found for image 756.
# Warning: No contours found for image 757.
# Warning: No contours found for image 758.
# Warning: No contours found for image 759.
# Warning: No contours found for image 760.
# Warning: No contours found for image 761.
# Warning: No contours found for image 762.
# Warning: No contours found for image 763.
# Warning: No contours found for image 764.
# Warning: No contours found for image 765.
# Warning: No contours found for image 766.
# Warning: No contours found for image 767.
# Warning: No contours found for image 768.
# Warning: No contours found for image 769.
# Warning: No contours found for image 770.
# Warning: No contours found for image 771.
# Warning: No contours found for image 772.
# Warning: No contours found for image 773.
# Warning: No contours found for image 774.
# Warning: No contours found for image 775.
# Warning: No contours found for image 776.
# Warning: No contours found for image 777.
# Warning: No contours found for image 778.
# Warning: No contours found for image 779.
# Warning: No contours found for image 780.
# Warning: No contours found for image 781.
# Warning: No contours found for image 782.
# Warning: No contours found for image 783.
# Warning: No contours found for image 784.
# Warning: No contours found for image 785.
# Warning: No contours found for image 786.
# Warning: No contours found for image 787.
# Warning: No contours found for image 788.
# Warning: No contours found for image 789.
# Warning: No contours found for image 790.
# Warning: No contours found for image 791.
# Warning: No contours found for image 792.
# Warning: No contours found for image 793.
# Warning: No contours found for image 794.
# Warning: No contours found for image 795.
# Warning: No contours found for image 796.
# Warning: No contours found for image 797.
# Warning: No contours found for image 798.
# Warning: No contours found for image 799.
# Warning: No contours found for image 800.
# Warning: No contours found for image 801.
# Warning: No contours found for image 802.
# Warning: No contours found for image 803.
# Warning: No contours found for image 804.
# Warning: No contours found for image 805.
# Warning: No contours found for image 806.
# Warning: No contours found for image 807.
# Warning: No contours found for image 808.
# Warning: No contours found for image 809.
# Warning: No contours found for image 810.
# Warning: No contours found for image 811.
# Warning: No contours found for image 812.
# Warning: No contours found for image 813.
# Warning: No contours found for image 814.
# Warning: No contours found for image 815.
# Warning: No contours found for image 816.
# Warning: No contours found for image 817.
# Warning: No contours found for image 818.
# Warning: No contours found for image 819.
# Warning: No contours found for image 820.
# Warning: No contours found for image 821.
# Warning: No contours found for image 822.
# Warning: No contours found for image 823.
# Warning: No contours found for image 824.
# Warning: No contours found for image 825.
# Warning: No contours found for image 826.
# Warning: No contours found for image 827.
# Warning: No contours found for image 828.
# Warning: No contours found for image 829.
# Warning: No contours found for image 830.
# Warning: No contours found for image 831.
# Warning: No contours found for image 832.
# Warning: No contours found for image 833.
# Warning: No contours found for image 834.
# Warning: No contours found for image 835.
# Warning: No contours found for image 836.
# Warning: No contours found for image 837.
# Warning: No contours found for image 838.
# Warning: No contours found for image 839.
# Warning: No contours found for image 840.
# Warning: No contours found for image 841.
# Warning: No contours found for image 842.
# Warning: No contours found for image 843.
# Warning: No contours found for image 844.
# Warning: No contours found for image 845.
# Warning: No contours found for image 846.
# Warning: No contours found for image 847.
# Warning: No contours found for image 848.
# Warning: No contours found for image 849.
# Warning: No contours found for image 850.
# Warning: No contours found for image 851.
# Warning: No contours found for image 852.
# Warning: No contours found for image 853.
# Warning: No contours found for image 854.
# Warning: No contours found for image 855.
# Warning: No contours found for image 856.
# Warning: No contours found for image 857.
# Warning: No contours found for image 858.
# Warning: No contours found for image 859.
# Warning: No contours found for image 860.
# Warning: No contours found for image 861.
# Warning: No contours found for image 862.
# Warning: No contours found for image 863.
# Warning: No contours found for image 864.
# Warning: No contours found for image 865.
# Warning: No contours found for image 866.
# Warning: No contours found for image 867.
# Warning: No contours found for image 868.
# Warning: No contours found for image 869.
# Warning: No contours found for image 870.
# Warning: No contours found for image 871.
# Warning: No contours found for image 872.
# Warning: No contours found for image 873.
# Warning: No contours found for image 874.
# Warning: No contours found for image 875.
# Warning: No contours found for image 876.
# Warning: No contours found for image 877.
# Warning: No contours found for image 878.
# Warning: No contours found for image 879.
# Warning: No contours found for image 880.
# Warning: No contours found for image 881.
# Warning: No contours found for image 882.
# Warning: No contours found for image 883.
# Warning: No contours found for image 884.
# Warning: No contours found for image 885.
# Warning: No contours found for image 886.
# Warning: No contours found for image 887.
# Warning: No contours found for image 888.
# Warning: No contours found for image 889.
# Warning: No contours found for image 890.
# Warning: No contours found for image 891.
# Warning: No contours found for image 892.
# Warning: No contours found for image 893.
# Warning: No contours found for image 894.
# Warning: No contours found for image 895.
# Warning: No contours found for image 896.
# Warning: No contours found for image 897.
# Warning: No contours found for image 898.
# Warning: No contours found for image 899.
# Warning: No contours found for image 900.
# Warning: No contours found for image 901.
# Warning: No contours found for image 902.
# Warning: No contours found for image 903.
# Warning: No contours found for image 904.
# Warning: No contours found for image 905.
# Warning: No contours found for image 906.
# Warning: No contours found for image 907.
# Warning: No contours found for image 908.
# Warning: No contours found for image 909.
# Warning: No contours found for image 910.
# Warning: No contours found for image 911.
# Warning: No contours found for image 912.
# Warning: No contours found for image 913.
# Warning: No contours found for image 914.
# Warning: No contours found for image 915.
# Warning: No contours found for image 916.
# Warning: No contours found for image 917.
# Warning: No contours found for image 918.
# Warning: No contours found for image 919.
# Warning: No contours found for image 920.
# Warning: No contours found for image 921.
# Warning: No contours found for image 922.
# Warning: No contours found for image 923.
# Warning: No contours found for image 924.
# Warning: No contours found for image 925.
# Warning: No contours found for image 926.
# Warning: No contours found for image 927.
# Warning: No contours found for image 928.
# Warning: No contours found for image 929.
# Warning: No contours found for image 930.
# Warning: No contours found for image 931.
# Warning: No contours found for image 932.
# Warning: No contours found for image 933.
# Warning: No contours found for image 934.
# Warning: No contours found for image 935.
# Warning: No contours found for image 936.
# Warning: No contours found for image 937.
# Warning: No contours found for image 938.
# Warning: No contours found for image 939.
# Warning: No contours found for image 940.
# Warning: No contours found for image 941.
# Warning: No contours found for image 942.
# Warning: No contours found for image 943.
# Warning: No contours found for image 944.
# Warning: No contours found for image 945.
# Warning: No contours found for image 946.
# Warning: No contours found for image 947.
# Warning: No contours found for image 948.
# Warning: No contours found for image 949.
# Warning: No contours found for image 950.
# Warning: No contours found for image 951.
# Warning: No contours found for image 952.
# Warning: No contours found for image 953.
# Warning: No contours found for image 954.
# Warning: No contours found for image 955.
# Warning: No contours found for image 956.
# Warning: No contours found for image 957.
# Warning: No contours found for image 958.
# Warning: No contours found for image 959.
# Warning: No contours found for image 960.
# Warning: No contours found for image 961.
# Warning: No contours found for image 962.
# Warning: No contours found for image 963.
# Warning: No contours found for image 964.
# Warning: No contours found for image 965.
# Warning: No contours found for image 966.
# Warning: No contours found for image 967.
# Warning: No contours found for image 968.
# Warning: No contours found for image 969.
# Warning: No contours found for image 970.
# Warning: No contours found for image 971.
# Warning: No contours found for image 972.
# Warning: No contours found for image 973.
# Warning: No contours found for image 974.
# Warning: No contours found for image 975.
# Warning: No contours found for image 976.
# Warning: No contours found for image 977.
# Warning: No contours found for image 978.
# Warning: No contours found for image 979.
# Warning: No contours found for image 980.
# Warning: No contours found for image 981.
# Warning: No contours found for image 982.
# Warning: No contours found for image 983.
# Warning: No contours found for image 984.
# Warning: No contours found for image 985.
# Warning: No contours found for image 986.
# Warning: No contours found for image 987.
# Warning: No contours found for image 988.
# Warning: No contours found for image 989.
# Warning: No contours found for image 990.
# Warning: No contours found for image 991.
# Warning: No contours found for image 992.
# Warning: No contours found for image 993.
# Warning: No contours found for image 994.
# Warning: No contours found for image 995.
# Warning: No contours found for image 996.
# Warning: No contours found for image 997.
# Warning: No contours found for image 998.
# Warning: No contours found for image 999.
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       1 ################################################################
#       2 ############################ TEST ##############################
#       3 ################################################################
# ----> 5 test_2_3_3(rotation_invariant, find_contour, apply_rotation, compute_descriptor_padding, linear_interpolation,images_p_a, feat_a)
#
# File ~/Documents/GitHub/group_28_repo/labs/utils/lab_02_utils.py:510, in test_2_3_3(rotation_invariant, find_contour, apply_rotation, compute_descriptor_padding, linear_interpolation, images_p_a, feat_a)
#     508 # Get descriptors for rotation imagescan
#     509 cnt_r_a = find_contour(apply_transformation(imgs=images_p_a, func=apply_rotation))
# --> 510 feat_r_a = compute_descriptor_padding(contours=linear_interpolation(cnt_r_a))
#     512 # Get invariant features
#     513 a = rotation_invariant(feat_a)
#
# Cell In[13], line 27, in linear_interpolation(contours, n_samples)
#      23 # ------------------
#      24 # Your code here ...
#      25 for i, contour in enumerate(contours):
#      26     # print(contour.shape)
# ---> 27     diff = np.sum(np.diff(contour, axis = 0)**2, axis = 1)
#      28     cumsum = np.cumsum(diff, axis = 0)
#      29     # Add (0, 0) to the beginning of the cumsum array
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/_core/fromnumeric.py:2389, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2386         return out
#    2387     return res
# -> 2389 return _wrapreduction(
#    2390     a, np.add, 'sum', axis, dtype, out,
#    2391     keepdims=keepdims, initial=initial, where=where
#    2392 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/_core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %% [markdown]
# * **Q4 (1 pt)**: Complet the function `scaling_invariant` to make the Fourier deciptor invariant to scaling. Does the error decrease after treatment for scaling invariance? Is it null? Why?
#     * **Answer**: ...

# %%
def scaling_invariant(features):
    """
    Make input Fourier descriptors invariant to scaling.

    Args
    ----
    features: np.ndarray (N, D)
        The Fourier descriptors of N images over D features.

    Return
    ------
    features_inv: np.ndarray (N, K)
        The Fourier descriptors invariant to scaling of N images 
        over K (K <= N) features.
    """

    # Set default values
    features_inv = np.zeros_like(features)
    
    # ------------------
    # Your code here ... 
    # ------------------

    return features_inv

# %%
################################################################
############################ TEST ##############################
################################################################

test_2_3_4(scaling_invariant, find_contour, apply_scaling, compute_descriptor_padding, linear_interpolation,images_p_a, feat_t_a, feat_a)

# %% [markdown]
# ---
# # PART 3 - Other descriptors [8 pts]
#
# ## 3.1 Distance map (5 pts)
#
# In this part, we will learn how to use a distance map as a feature descriptor.
#
# * **Q1 (1 pt)**: To compute a distance map we first need a reference pattern. Complete the function `reference_pattern`. The function takes as input a list of images and computes the reference pattern as the average of all shapes.

# %%
def reference_pattern(imgs):
    """
    Compute the reference pattern for a given set of images. The reference pattern 
    is estimated as the average of all images of the same pattern.

    Args
    ----
    imgs: np.ndarray (N, 28, 28)
        Source images
        
    Return
    ------
    pattern: np.ndarray (28, 28)
        Thresholded reference pattern that is the average of all shapes.
    """

    # Initialize pattern
    pattern = np.zeros((imgs[0].shape[0], imgs[0].shape[1]))
    
    # ------------------
    # Your code here ... 
    # ------------------
   
    return pattern

# %%
################################################################
############################ TEST ##############################
################################################################

pattern_a, pattern_b = test_3_1(reference_pattern, images_p_a, images_p_b)

# %% [markdown]
# * **Q2 (2 pts)**: The next part will be to compute a distance map from the generated pattern. By pre-computing the distance map we can speedup the inference time. Complete the function `compute_distance_map`. We expect the values of the map to represent the distances to the closest pattern contour. If needed, can take advantage of the functions you wrote in PART2 to detect and resample contours.

# %%
def compute_distance_map(pattern: np.ndarray):
    """
    Compute the distance map for the given pattern. The values of the map are computed as 
    the distance to the closest pattern contour.

    Args
    ----
    pattern: np.ndarray (28, 28)
        Pattern to process

    Return
    ------
    distance_map: np.ndarray (28, 28)
        Distance map where each entry is the distance to the closest pattern contour (shortest 
        distance to pattern)
    """
    
    # Initialize dummy values
    distance_map = np.zeros_like(pattern)
    
    # ------------------
    # Your code here ... 
    # ------------------
    
    return distance_map

# %%
################################################################
############################ TEST ##############################
################################################################

map_a, map_b = test_3_1_2(compute_distance_map, pattern_a, pattern_b)

# %% [markdown]
# * **Q3 (2 pts)**: For the last part, implement the function `compute_distance` that uses the precomputed distance map to evaluate the distance to all images. Note that for each image you should return the average of distances. As before, for each digit, you can compute the contour and estimate the point-to-point distance by evaluating the distance map at the xy contour coordinates.

# %%
def compute_distance(imgs, d_map):
    """
    Compute the distances for each image with respect to the reference pattern using the precomputed 
    distance map. The final distance is the average of all distances from the image's contour points 
    to the reference pattern.

    Args
    ----
    imgs: np.ndarray (N, 28, 28)
        Source images
    d_map: np.ndarray (28, 28)
        The precomputed distance map where each entry is the distance to the closest pattern contour 
        (shortest distance to pattern)
    
    Return
    ------
    dist: np.ndarray (N, )
        Averaged distance to pattern for each input image.
    """
    
    # Default values
    dist = np.zeros(len(imgs))

    # ------------------
    # Your code here ... 
    # ------------------
    
    return dist

# %%
################################################################
############################ TEST ##############################
################################################################

test_3_1_3(compute_distance, images_p_a, images_p_b, map_a, map_b)

# %% [markdown]
# ## 3.2 Others (3 pts)
#
# For the last part of the lab, we will compute other various visual features.
#
# * **Q1: (2 pts)**: Implement the function `compute_features` that estimates the digit's perimeter, area, compacity, and rectangularity. You can use the lecture to look for the definition of each feature. To help you with this task we strongly recommend using the `regionprops` ([doc](https://scikit-image.org/docs/stable/api/skimage.measure.html#skimage.measure.regionprops)) from scikit-image.
# * **Q2: (1 pt)**: Which feature(s) seem(s) to show the best results to distinguish between both digits? (justify)
#     * **Answer**: ...

# %%
def compute_features(imgs: np.ndarray):
    """
    Compute compacity for each input image.
    
    Args
    ----
    imgs: np.ndarray (N, 28, 28)
        Source images
        
    Return
    ------
    f_peri: np.ndarray (N,)
        Estimated perimeter length for each image
    f_area: np.ndarray (N,)
        Estimated area for each image
    f_comp: np.ndarray (N,)
        Estimated compacity for each image
    f_rect: np.ndarray (N,)
        Estimated rectangularity for each image
    """

    f_peri = np.zeros(len(imgs))
    f_area = np.zeros(len(imgs))
    f_comp = np.zeros(len(imgs))
    f_rect = np.zeros(len(imgs))
    
    # ------------------
    # Your code here ... 
    # ------------------

    return f_peri, f_area, f_comp, f_rect

# %%
################################################################
############################ TEST ##############################
################################################################

test_3_2(compute_features, images_p_a, images_p_b)
